# %%
import os, sys
os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable
print("PYSPARK_PYTHON =", os.environ["PYSPARK_PYTHON"])
print("PYSPARK_DRIVER_PYTHON =", os.environ["PYSPARK_DRIVER_PYTHON"])
# Out:
# PYSPARK_PYTHON = c:\Users\zbela\AppData\Local\Programs\Python\Python311\python.exe
# PYSPARK_DRIVER_PYTHON = c:\Users\zbela\AppData\Local\Programs\Python\Python311\python.exe

# %%
import requests
from io import StringIO

url = "https://people.sc.fsu.edu/~jburkardt/data/csv/airtravel.csv"

response = requests.get(url, timeout=20)
response.raise_for_status()

csv_text = response.text
# csv_text[:200]

# %%
import pandas as pd

pdf = pd.read_csv(StringIO(csv_text))
df = spark.createDataFrame(pdf)


# display(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 pdf = pd.read_csv(StringIO(csv_text))
#       4 df = spark.createDataFrame(pdf)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.createOrReplaceTempView("airtravel")

# %%
# %sql 
SELECT count(*) FROM airtravel --LIMIT 10
# Out:
# DataFrame[count(1): bigint]
